# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time

# %%
# !python deeplab/eval.py --logtostderr --eval_split="val" --model_variant="mobilenet_v2" --eval_crop_size='513,513' --dataset="pascal_voc_seg" --eval_interval_secs=20 --max_number_of_evaluations=1 --dataset_dir=deeplab/datasets/pascal_voc_seg/tfrecord --eval_logdir=eval_log --checkpoint_dir=deeplabv3_mnv2_pascal_train_aug
# Out:
# WARNING:tensorflow:From /home/cl4294/models/research/deeplab/core/conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:From deeplab/eval.py:233: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From deeplab/eval.py:91: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W1217 20:34:58.191328 140341736810304 module_wrapper.py:139] From deeplab/eval.py:91: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From deeplab/eval.py:91: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W1217 20:34:58.191509 140341736810304 module_wrapper.py:139] From deeplab/eval.py:91: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
# only record the time the model takes to inference on val (exclude the time it takes to do post-processing)
# 20:35:00.505691 
# 20:35:02.038912
t_diff = 2.038912 - 0.505691

print("the time it takes to eval with non quantized model", t_diff)
print("throughput: {} images per second".format(1448 / t_diff))
# Out:
# the time it takes to eval with non quantized model 1.5332209999999997
# throughput: 944.4170148987004 images per second

# %%
# !python deeplab/eval.py --logtostderr --eval_split="val" --model_variant="mobilenet_v2" --eval_crop_size='513,513' --dataset="pascal_voc_seg" --eval_interval_secs=20 --max_number_of_evaluations=1 --dataset_dir=deeplab/datasets/pascal_voc_seg/tfrecord --eval_logdir=eval_log --checkpoint_dir=ckpt
# Out:
# WARNING:tensorflow:From /home/cl4294/models/research/deeplab/core/conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:From deeplab/eval.py:233: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From deeplab/eval.py:91: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W1217 20:42:18.829177 140129315268416 module_wrapper.py:139] From deeplab/eval.py:91: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From deeplab/eval.py:91: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W1217 20:42:18.829356 140129315268416 module_wrapper.py:139] From deeplab/eval.py:91: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
# only record the time the model takes to inference on val (exclude the time it takes to do post-processing)
#20:42:21.086122 
#20:42:22.548271

t_diff = 22.548271 - 21.086122
print("the time it takes to eval with quantized model", t_diff)
print("throughput: {} images per second".format(1448 / t_diff))
# Out:
# the time it takes to eval with quantized model 1.4621490000000001
# throughput: 990.3231476409038 images per second

# %% [markdown]
# ## visualization

# %%
# !python deeplab/vis.py --logtostderr --vis_split="val" --model_variant="mobilenet_v2" --output_stride=16 --vis_crop_size='531,531' --dataset="pascal_voc_seg" --colormap_type="pascal" --checkpoint_dir=ckpt --vis_logdir=vis_log1 --dataset_dir='deeplab/datasets/pascal_voc_seg/tfrecord'
# Out:
# WARNING:tensorflow:From /home/cl4294/models/research/deeplab/core/conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:From deeplab/vis.py:329: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From deeplab/vis.py:195: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W1217 20:59:32.821797 140024782669632 module_wrapper.py:139] From deeplab/vis.py:195: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From deeplab/vis.py:195: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W1217 20:59:32.821953 140024782669632 module_wrapper.py:139] From deeplab/vis.py:195: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
# !tensorboard --logdir='eval_test_log' --port=5002
# Out:
# TensorBoard 1.15.0 at http://instance-4:5002/ (Press CTRL+C to quit)
# ^C

# %%
# !python deeplab/vis.py --logtostderr --vis_split="val" --model_variant="mobilenet_v2" --output_stride=16 --vis_crop_size='531,531' --dataset="pascal_voc_seg" --colormap_type="pascal" --checkpoint_dir=deeplabv3_mnv2_pascal_train_aug --vis_logdir=vis_log2 --dataset_dir='deeplab/datasets/pascal_voc_seg/tfrecord'
# Out:
# WARNING:tensorflow:From /home/cl4294/models/research/deeplab/core/conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:From deeplab/vis.py:329: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From deeplab/vis.py:195: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W1217 21:28:55.052998 140321879205696 module_wrapper.py:139] From deeplab/vis.py:195: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From deeplab/vis.py:195: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W1217 21:28:55.053167 140321879205696 module_wrapper.py:139] From deeplab/vis.py:195: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
img1 = mpimg.imread('vis_log1/segmentation_results/000000_image.png')
pred1 = mpimg.imread('vis_log1/segmentation_results/000000_prediction.png') # quantized int8 
pred2 = mpimg.imread('vis_log2/segmentation_results/000000_prediction.png') # non quantized float32
plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(pred1)
plt.subplot(1,3,3)
plt.imshow(pred2)

# %%
img1 = mpimg.imread('vis_log1/segmentation_results/000200_image.png')
pred1 = mpimg.imread('vis_log1/segmentation_results/000200_prediction.png') # quantized int8 
pred2 = mpimg.imread('vis_log2/segmentation_results/000200_prediction.png') # non quantized float32
plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(pred1)
plt.subplot(1,3,3)
plt.imshow(pred2)

# %%
img1 = mpimg.imread('vis_log1/segmentation_results/000400_image.png')
pred1 = mpimg.imread('vis_log1/segmentation_results/000400_prediction.png') # quantized int8 
pred2 = mpimg.imread('vis_log2/segmentation_results/000400_prediction.png') # non quantized float32
plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(pred1)
plt.subplot(1,3,3)
plt.imshow(pred2)

# %%
img1 = mpimg.imread('vis_log1/segmentation_results/001000_image.png')
pred1 = mpimg.imread('vis_log1/segmentation_results/001000_prediction.png') # quantized int8 
pred2 = mpimg.imread('vis_log2/segmentation_results/001000_prediction.png') # non quantized float32
plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(pred1)
plt.subplot(1,3,3)
plt.imshow(pred2)

# %%
img1 = mpimg.imread('vis_log1/segmentation_results/001200_image.png')
pred1 = mpimg.imread('vis_log1/segmentation_results/001200_prediction.png') # quantized int8 
pred2 = mpimg.imread('vis_log2/segmentation_results/001200_prediction.png') # non quantized float32
plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(pred1)
plt.subplot(1,3,3)
plt.imshow(pred2)

# %%
img1 = mpimg.imread('vis_log1/segmentation_results/000800_image.png')
pred1 = mpimg.imread('vis_log1/segmentation_results/000800_prediction.png') # quantized int8 
pred2 = mpimg.imread('vis_log2/segmentation_results/000800_prediction.png') # non quantized float32
plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(pred1)
plt.subplot(1,3,3)
plt.imshow(pred2)

# %%
img1 = mpimg.imread('vis_log1/segmentation_results/001400_image.png')
pred1 = mpimg.imread('vis_log1/segmentation_results/001400_prediction.png') # quantized int8 
pred2 = mpimg.imread('vis_log2/segmentation_results/001400_prediction.png') # non quantized float32
plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(pred1)
plt.subplot(1,3,3)
plt.imshow(pred2)
